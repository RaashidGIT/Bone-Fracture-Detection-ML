# %% [markdown]
# <a href="https://colab.research.google.com/github/RaashidGIT/Bone-Fracture-Detection-ML/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
